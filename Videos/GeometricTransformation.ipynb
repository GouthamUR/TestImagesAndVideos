# %%
import os
import cv2
import numpy as np


def generate_transformation_video(
    image,
    transform="rotation",
    output="output.mp4",
    steps=100,
    fps=30
):
    """
    Generate a video showing progressive transformation of an image.
    Supported transforms:
    rotation, scaling, translation, zoom_in, zoom_out,
    tilt, flip, blur, brightness,
    skew_horizontal, perspective, shear, stretch, compression
    """
    # Load image
    if isinstance(image, str):
        img = cv2.imread(image, cv2.IMREAD_UNCHANGED)
        if img is None:
            raise ValueError(f"Could not load image from path: {image}")
    else:
        img = image

    h, w = img.shape[:2]

    # Video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output, fourcc, fps, (w, h))

    for i in range(steps):
        progress = i / (steps - 1) if steps > 1 else 1.0

        if transform == "rotation":
            angle = progress * 360
            M = cv2.getRotationMatrix2D((w//2, h//2), angle, 1)
            frame = cv2.warpAffine(img, M, (w, h))

        elif transform == "scaling":
            scale = 1 + 0.5 * progress
            M = cv2.getRotationMatrix2D((w//2, h//2), 0, scale)
            frame = cv2.warpAffine(img, M, (w, h))

        elif transform == "translation":
            tx = int(progress * 50)
            ty = int(progress * 50)
            M = np.float32([[1, 0, tx], [0, 1, ty]])
            frame = cv2.warpAffine(img, M, (w, h))

        elif transform == "zoom_in":
            crop = int(progress * min(h, w) // 4)
            zoom = img[crop:h-crop, crop:w-crop] if crop < h//2 and crop < w//2 else img
            frame = cv2.resize(zoom, (w, h))

        elif transform == "zoom_out":
            small = cv2.resize(img, (int(w*(1-progress*0.5)), int(h*(1-progress*0.5))))
            border_v = (h - small.shape[0]) // 2
            border_h = (w - small.shape[1]) // 2
            frame = cv2.copyMakeBorder(small, border_v, h-small.shape[0]-border_v,
                                       border_h, w-small.shape[1]-border_h,
                                       cv2.BORDER_CONSTANT, value=(0,0,0))

        elif transform == "tilt":
            pts1 = np.float32([[0,0],[w-1,0],[0,h-1]])
            pts2 = np.float32([[0,0],[w-1, int(0.3*h*progress)], [int(0.2*w*progress), h-1]])
            M = cv2.getAffineTransform(pts1, pts2)
            frame = cv2.warpAffine(img, M, (w, h))

        elif transform == "flip":
            if progress < 0.5:
                frame = img.copy()
            else:
                frame = cv2.flip(img, 1)

        elif transform == "blur":
            k = int(1 + progress * 20)
            if k % 2 == 0:
                k += 1
            frame = cv2.GaussianBlur(img, (k, k), 0)

        elif transform == "brightness":
            alpha = 1.0 + 0.5 * progress
            beta = int(50 * progress)
            frame = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)

        elif transform == "skew_horizontal":
            skew_matrix = np.array([[1, 0.5*progress, 0], [0, 1, 0]], dtype=np.float32)
            frame = cv2.warpAffine(img, skew_matrix, (int(w*(1+0.5*progress)), h))

        elif transform == "perspective":
            pts1 = np.float32([[50, 50], [w-50, 50], [50, h-50], [w-50, h-50]])
            pts2 = np.float32([
                [0, 0],
                [w, 0],
                [50 + 100*progress, h],
                [w-50 - 100*progress, h]
            ])
            M = cv2.getPerspectiveTransform(pts1, pts2)
            frame = cv2.warpPerspective(img, M, (w, h))

        elif transform == "shear":
            shear_matrix = np.float32([[1, progress, 0], [0, 1, 0]])
            frame = cv2.warpAffine(img, shear_matrix, (int(w + h*progress), h))

        elif transform == "stretch":
            stretched_w = int(w * (1 + 0.5 * progress))
            stretched = cv2.resize(img, (stretched_w, h))

            if stretched_w > w:
                # Crop center
                start_x = (stretched_w - w) // 2
                frame = stretched[:, start_x:start_x + w]
            else:
                # Pad if smaller
                pad_left = (w - stretched_w) // 2
                pad_right = w - stretched_w - pad_left
                frame = cv2.copyMakeBorder(stretched, 0, 0, pad_left, pad_right,
                                        cv2.BORDER_CONSTANT, value=(0, 0, 0))


        elif transform == "compression":
            frame = cv2.resize(img, (max(1, int(w*(1-progress*0.5))), h))
            frame = cv2.copyMakeBorder(frame, 0, 0, (w-frame.shape[1])//2,
                                       w-frame.shape[1]-(w-frame.shape[1])//2,
                                       cv2.BORDER_CONSTANT, value=(0,0,0))

        else:
            raise ValueError(f"Unknown transform: {transform}")

        # Resize to match output video size
        frame_resized = cv2.resize(frame, (w, h))
        out.write(frame_resized)

    out.release()
    print(f"Saved video: {output}")

# %%
def process_folder(input_folder, output_root="Videos", steps=100, fps=30):
    """
    Process all images in a folder and generate videos for each transformation.
    Folder structure:
    Videos/
      image_name/
        rotation.mp4
        scaling.mp4
        translation.mp4
        zoom_in.mp4
        zoom_out.mp4
        tilt.mp4
        flip.mp4
        blur.mp4
        brightness.mp4
        skew_horizontal.mp4
        perspective.mp4
        shear.mp4
        stretch.mp4
        compression.mp4
    """
    os.makedirs(output_root, exist_ok=True)

    # All supported transformations
    transforms = [
        "rotation",
        "scaling",
        "translation",
        "zoom_in",
        "zoom_out",
        "tilt",
        "flip",
        "blur",
        "brightness",
        "skew_horizontal",
        "perspective",
        "shear",
        "stretch",
        "compression"
    ]

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
            image_path = os.path.join(input_folder, filename)
            image_name, _ = os.path.splitext(filename)

            # Subfolder for this image
            image_out_folder = os.path.join(output_root, image_name)
            os.makedirs(image_out_folder, exist_ok=True)

            print(f"\n Processing {filename}...")

            # Generate a video for each transform
            for t in transforms:
                output_path = os.path.join(image_out_folder, f"{t}.mp4")
                generate_transformation_video(
                    image_path,
                    transform=t,
                    output=output_path,
                    steps=steps,
                    fps=fps
                )

    print(f"\n All transformations completed. Results in: {output_root}")

# %%
process_folder("outputs/selected", output_root="Videos2", steps=80, fps=30)
# Out:
#  Processing P0016.png...
# Saved video: Videos2\P0016\rotation.mp4
# Saved video: Videos2\P0016\scaling.mp4
# Saved video: Videos2\P0016\translation.mp4
# Saved video: Videos2\P0016\zoom_in.mp4
# Saved video: Videos2\P0016\zoom_out.mp4
# Saved video: Videos2\P0016\tilt.mp4
# Saved video: Videos2\P0016\flip.mp4
# Saved video: Videos2\P0016\blur.mp4
# Saved video: Videos2\P0016\brightness.mp4
# Saved video: Videos2\P0016\skew_horizontal.mp4
# Saved video: Videos2\P0016\perspective.mp4
# Saved video: Videos2\P0016\shear.mp4
# Saved video: Videos2\P0016\stretch.mp4
# Saved video: Videos2\P0016\compression.mp4
#
#  Processing P0107.png...
# Saved video: Videos2\P0107\rotation.mp4
# Saved video: Videos2\P0107\scaling.mp4
# Saved video: Videos2\P0107\translation.mp4
# Saved video: Videos2\P0107\zoom_in.mp4
# Saved video: Videos2\P0107\zoom_out.mp4
# Saved video: Videos2\P0107\tilt.mp4
# Saved video: Videos2\P0107\flip.mp4
# Saved video: Videos2\P0107\blur.mp4
# Saved video: Videos2\P0107\brightness.mp4
# Saved video: Videos2\P0107\skew_horizontal.mp4
# Saved video: Videos2\P0107\perspective.mp4
# Saved video: Videos2\P0107\shear.mp4
# Saved video: Videos2\P0107\stretch.mp4
# Saved video: Videos2\P0107\compression.mp4
#
#  Processing P0153.png...
# Saved video: Videos2\P0153\rotation.mp4
# Saved video: Videos2\P0153\scaling.mp4
# Saved video: Videos2\P0153\translation.mp4
# Saved video: Videos2\P0153\zoom_in.mp4
# Saved video: Videos2\P0153\zoom_out.mp4
# Saved video: Videos2\P0153\tilt.mp4
# Saved video: Videos2\P0153\flip.mp4
# Saved video: Videos2\P0153\blur.mp4
# Saved video: Videos2\P0153\brightness.mp4
# Saved video: Videos2\P0153\skew_horizontal.mp4
# Saved video: Videos2\P0153\perspective.mp4
# Saved video: Videos2\P0153\shear.mp4
# Saved video: Videos2\P0153\stretch.mp4
# Saved video: Videos2\P0153\compression.mp4
#
#  Processing P0197.png...
# Saved video: Videos2\P0197\rotation.mp4
# Saved video: Videos2\P0197\scaling.mp4
# Saved video: Videos2\P0197\translation.mp4
# Saved video: Videos2\P0197\zoom_in.mp4
# Saved video: Videos2\P0197\zoom_out.mp4
# Saved video: Videos2\P0197\tilt.mp4
# Saved video: Videos2\P0197\flip.mp4
# Saved video: Videos2\P0197\blur.mp4
# Saved video: Videos2\P0197\brightness.mp4
# Saved video: Videos2\P0197\skew_horizontal.mp4
# Saved video: Videos2\P0197\perspective.mp4
# Saved video: Videos2\P0197\shear.mp4
# Saved video: Videos2\P0197\stretch.mp4
# Saved video: Videos2\P0197\compression.mp4
#
#  Processing P0278.png...
# Saved video: Videos2\P0278\rotation.mp4
# Saved video: Videos2\P0278\scaling.mp4
# Saved video: Videos2\P0278\translation.mp4
# Saved video: Videos2\P0278\zoom_in.mp4
# Saved video: Videos2\P0278\zoom_out.mp4
# Saved video: Videos2\P0278\tilt.mp4
# Saved video: Videos2\P0278\flip.mp4
# Saved video: Videos2\P0278\blur.mp4
# Saved video: Videos2\P0278\brightness.mp4
# Saved video: Videos2\P0278\skew_horizontal.mp4
# Saved video: Videos2\P0278\perspective.mp4
# Saved video: Videos2\P0278\shear.mp4
# Saved video: Videos2\P0278\stretch.mp4
# Saved video: Videos2\P0278\compression.mp4
#
#  Processing P0592.png...
# Saved video: Videos2\P0592\rotation.mp4
# Saved video: Videos2\P0592\scaling.mp4
# Saved video: Videos2\P0592\translation.mp4
# Saved video: Videos2\P0592\zoom_in.mp4
# Saved video: Videos2\P0592\zoom_out.mp4
# Saved video: Videos2\P0592\tilt.mp4
# Saved video: Videos2\P0592\flip.mp4
# Saved video: Videos2\P0592\blur.mp4
# Saved video: Videos2\P0592\brightness.mp4
# Saved video: Videos2\P0592\skew_horizontal.mp4
# Saved video: Videos2\P0592\perspective.mp4
# Saved video: Videos2\P0592\shear.mp4
# Saved video: Videos2\P0592\stretch.mp4
# Saved video: Videos2\P0592\compression.mp4
#
#  Processing P0739.png...
# Saved video: Videos2\P0739\rotation.mp4
# Saved video: Videos2\P0739\scaling.mp4
# Saved video: Videos2\P0739\translation.mp4
# Saved video: Videos2\P0739\zoom_in.mp4
# Saved video: Videos2\P0739\zoom_out.mp4
# Saved video: Videos2\P0739\tilt.mp4
# Saved video: Videos2\P0739\flip.mp4
# Saved video: Videos2\P0739\blur.mp4
# Saved video: Videos2\P0739\brightness.mp4
# Saved video: Videos2\P0739\skew_horizontal.mp4
# Saved video: Videos2\P0739\perspective.mp4
# Saved video: Videos2\P0739\shear.mp4
# Saved video: Videos2\P0739\stretch.mp4
# Saved video: Videos2\P0739\compression.mp4
#
#  Processing P0741.png...
# Saved video: Videos2\P0741\rotation.mp4
# Saved video: Videos2\P0741\scaling.mp4
# Saved video: Videos2\P0741\translation.mp4
# Saved video: Videos2\P0741\zoom_in.mp4
# Saved video: Videos2\P0741\zoom_out.mp4
# Saved video: Videos2\P0741\tilt.mp4
# Saved video: Videos2\P0741\flip.mp4
# Saved video: Videos2\P0741\blur.mp4
# Saved video: Videos2\P0741\brightness.mp4
# Saved video: Videos2\P0741\skew_horizontal.mp4
# Saved video: Videos2\P0741\perspective.mp4
# Saved video: Videos2\P0741\shear.mp4
# Saved video: Videos2\P0741\stretch.mp4
# Saved video: Videos2\P0741\compression.mp4
#
#  Processing P1068.png...
# Saved video: Videos2\P1068\rotation.mp4
# Saved video: Videos2\P1068\scaling.mp4
# Saved video: Videos2\P1068\translation.mp4
# Saved video: Videos2\P1068\zoom_in.mp4
# Saved video: Videos2\P1068\zoom_out.mp4
# Saved video: Videos2\P1068\tilt.mp4
# Saved video: Videos2\P1068\flip.mp4
# Saved video: Videos2\P1068\blur.mp4
# Saved video: Videos2\P1068\brightness.mp4
# Saved video: Videos2\P1068\skew_horizontal.mp4
# Saved video: Videos2\P1068\perspective.mp4
# Saved video: Videos2\P1068\shear.mp4
# Saved video: Videos2\P1068\stretch.mp4
# Saved video: Videos2\P1068\compression.mp4
#
#  Processing P1320.png...
# Saved video: Videos2\P1320\rotation.mp4
# Saved video: Videos2\P1320\scaling.mp4
# Saved video: Videos2\P1320\translation.mp4
# Saved video: Videos2\P1320\zoom_in.mp4
# Saved video: Videos2\P1320\zoom_out.mp4
# Saved video: Videos2\P1320\tilt.mp4
# Saved video: Videos2\P1320\flip.mp4
# Saved video: Videos2\P1320\blur.mp4
# Saved video: Videos2\P1320\brightness.mp4
# Saved video: Videos2\P1320\skew_horizontal.mp4
# Saved video: Videos2\P1320\perspective.mp4
# Saved video: Videos2\P1320\shear.mp4
# Saved video: Videos2\P1320\stretch.mp4
# Saved video: Videos2\P1320\compression.mp4
#
#  All transformations completed. Results in: Videos2
